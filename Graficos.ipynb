# %%
# %matplotlib inline

# %%
from sklearn.datasets import *
import statsmodels.api as sm
import matplotlib.pyplot as plt
import numpy as np

import pandas as pd
# Out:
# /usr/local/lib/python3.5/dist-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
data = make_regression(100, 1, shuffle=False)[0]

# %%
data = np.random.randint(-10, 12, 50)

# %%
plt.figure(figsize=(10, 6))

plt.plot(np.add.accumulate(data), "gray")
data_accumulated = np.add.accumulate(data)
plt.savefig("acf_co2.png", bbox_inches="tight")
plt.savefig("serie_exemplo.png", bbox_inches="tight")

# %%
CO2 = pd.read_csv("weekly_in_situ_co2_mlo.csv", comment="\"", names=["Dates", "Reads"], parse_dates=["Dates"], index_col="Dates")

# %%
plt.figure(figsize=(10,5))
plt.plot(CO2, "gray")
plt.ylabel("CO2")
plt.xlabel("Data")

plt.savefig("co2.png", bbox_inches="tight")

# %%
plt.figure(figsize=(10,5))
plt.plot(CO2, "gray")
plt.ylabel("CO2")
plt.xlabel("Data")

plt.savefig("co2.png", bbox_inches="tight")

# %%
fig = plt.set_cmap("gray")

plot = sm.graphics.tsa.plot_acf(CO2, lags=25, zero=False)
plot.set_size_inches((10,7.5))

plot.savefig("acf_co2.png", bbox_inches="tight")

# %%
a.get_size_inches()
# Out:
# array([ 6.,  4.])

# %%
plt.figure(figsize=(10,5))
plt.plot(CO2.diff(), "gray")
plt.ylabel("CO2")
plt.xlabel("Data")

plt.savefig("co2_diff.png", bbox_inches="tight")

# %%
fig = plt.set_cmap("gray")

plot = sm.graphics.tsa.plot_acf(CO2.diff().dropna(), lags=25, zero=False)
plot.set_size_inches((10,7.5))

plot.savefig("acf_co2_diff.png", bbox_inches="tight")

# %%
sm.tsa.x13_arima_analysis(CO2.resample("W").si, x12path="/srv/x13", prefer_x13=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/statsmodels/tsa/x13.py in pandas_to_series_spec(x)
#     289     try:
# --> 290         period = _freq_to_period[x.index.freqstr]
#     291     except (AttributeError, ValueError):
#
# /usr/local/lib/python3.5/dist-packages/statsmodels/tsa/x13.py in __getitem__(self, key)
#      31     def __getitem__(self, key):
# ---> 32         if key.startswith('M'):
#      33             return 12
#
# AttributeError: 'NoneType' object has no attribute 'startswith'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-fb94f8e95eab> in <module>()
# ----> 1 sm.tsa.x13_arima_analysis(CO2, x12path="/srv/x13", prefer_x13=True)
#
# ...

# %%
CO2.index.freqstr
